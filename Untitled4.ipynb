# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# ! kaggle datasets download -d gargmanas/parkinsonsdataset

# %%
parkinsons_voice_data = pd.read_csv('/content/parkinsons.csv')

# %%
parkinsons_voice_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
parkinsons_voice_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
parkinsons_voice_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
parkinsons_voice_data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# 1 - Parkinson
# 0 - Healthy

# %%
parkinsons_voice_data.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
X = parkinsons_voice_data.drop(columns = ['name','status'],axis=1)
y = parkinsons_voice_data['status']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.63239631, -0.02731081, -0.87985049, ..., -0.97586547,
#         -0.55160318,  0.07769494],
#        [-1.05512719, -0.83337041, -0.9284778 , ...,  0.3981808 ,
#         -0.61014073,  0.39291782],
#        [ 0.02996187, -0.29531068, -1.12211107, ..., -0.43937044,
#         -0.62849605, -0.50948408],
#        ...,
#        [-0.9096785 , -0.6637302 , -0.160638  , ...,  1.22001022,
#         -0.47404629, -0.2159482 ],
#        [-0.35977689,  0.19731822, -0.79063679, ..., -0.17896029,
#         -0.47272835,  0.28181221],
#        [ 1.01957066,  0.19922317, -0.61914972, ..., -0.716232  ,
#          1.23632066, -0.05829386]])

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# ! kaggle datasets download -d mohammadrezabaqery/parkinson-dataset
# Out:
# Downloading parkinson-dataset.zip to /content
#  81% 17.0M/21.0M [00:00<00:00, 46.6MB/s]
# 100% 21.0M/21.0M [00:00<00:00, 50.7MB/s]

# %%
# ! unzip parkinson-dataset.zip
# Out:
# Archive:  parkinson-dataset.zip
#   inflating: spiral/testing/healthy/V01HE01.png
#   inflating: spiral/testing/healthy/V02HE01.png
#   inflating: spiral/testing/healthy/V03HE1.png
#   inflating: spiral/testing/healthy/V04HE01.png
#   inflating: spiral/testing/healthy/V05HE01.png
#   inflating: spiral/testing/healthy/V06HE01.png
#   inflating: spiral/testing/healthy/V07HE01.png
#   inflating: spiral/testing/healthy/V08HE01.png
#   inflating: spiral/testing/healthy/V09HE01.png
#   inflating: spiral/testing/healthy/V10HE01.png
#   inflating: spiral/testing/healthy/V11HE01.png
#   inflating: spiral/testing/healthy/V55HE12.png
#   inflating: spiral/testing/healthy/V55HE13.png
#   inflating: spiral/testing/healthy/V55HE14.png
#   inflating: spiral/testing/healthy/V55HE15.png
#   inflating: spiral/testing/parkinson/V01PE01.png
#   inflating: spiral/testing/parkinson/V02PE01.png
#   inflating: spiral/testing/parkinson/V03PE01.png
#   inflating: spiral/testing/parkinson/V03PE04.png
#   inflating: spiral/testing/parkinson/V03PE07.png
#   inflating: spiral/testing/parkinson/V04PE01.png
#   inflating: spiral/testing/parkinson/V05PE01.png
#   inflating: spiral/testing/parkinson/V06PE01.png
#   inflating: spiral/testing/parkinson/V07PE01.png
#   inflating: spiral/testing/parkinson/V08PE01.png
#   inflating: spiral/testing/parkinson/V09PE01.png
#   inflating: spiral/testing/parkinson/V10PE03.png
#   inflating: spiral/testing/parkinson/V11PE03.png
#   inflating: spiral/testing/parkinson/V14PE03.png
#   inflating: spiral/testing/parkinson/V15PE01.png
#   inflating: spiral/training/healthy/V01HE02.png
#   inflating: spiral/training/healthy/V01HE03.png
#   inflating: spiral/training/healthy/V02HE02.png
#   inflating: spiral/training/healthy/V02HE03.png
#   inflating: spiral/training/healthy/V03HE2.png
#   inflating: spiral/training/healthy/V03HE3.png
#   inflating: spiral/training/healthy/V04HE02.png
#   inflating: spiral/training/healthy/V04HE03.png
#   inflating: spiral/training/healthy/V05HE02.png
#   inflating: spiral/training/healthy/V05HE03.png
#   inflating: spiral/training/healthy/V06HE02.png
#   inflating: spiral/training/healthy/V06HE03.png
#   inflating: wave/training/healthy/V55HO07.png
#   inflating: wave/training/healthy/V55HO12.png
#   inflating: wave/training/healthy/V55HO13.png
#   inflating: wave/training/healthy/V55HO14.png
#   inflating: wave/training/healthy/V55HO15.png
#   inflating: wave/training/parkinson/V01PO02.png
#   inflating: wave/training/parkinson/V01PO03.png
#   inflating: wave/training/parkinson/V02PO02.png
#   inflating: wave/training/parkinson/V02PO03.png
#   inflating: wave/training/parkinson/V03PO02.png
#   inflating: wave/training/parkinson/V03PO03.png
#   inflating: wave/training/parkinson/V03PO05.png
#   inflating: wave/training/parkinson/V03PO06.png
#   inflating: wave/training/parkinson/V03PO08.png
#   inflating: wave/training/parkinson/V03PO09.png
#   inflating: wave/training/parkinson/V04PO02.png
#   inflating: wave/training/parkinson/V04PO03.png
#   inflating: wave/training/parkinson/V05PO02.png
#   inflating: wave/training/parkinson/V05PO03.png
#   inflating: wave/training/parkinson/V06PO02.png
#   inflating: wave/training/parkinson/V06PO03.png
#   inflating: wave/training/parkinson/V07PO02.png
#   inflating: wave/training/parkinson/V07PO03.png
#   inflating: wave/training/parkinson/V08PO02.png
#   inflating: wave/training/parkinson/V08PO03.png
#   inflating: wave/training/parkinson/V09PO02.png
#   inflating: wave/training/parkinson/V09PO03.png
#   inflating: wave/training/parkinson/V10PO02.png
#   inflating: wave/training/parkinson/V10PO03.png
#   inflating: wave/training/parkinson/V11PO02.png
#   inflating: wave/training/parkinson/V11PO03.png
#   inflating: wave/training/parkinson/V12PO01.png
#   inflating: wave/training/parkinson/V12PO02.png
#   inflating: wave/training/parkinson/V12PO03.png
#   inflating: wave/training/parkinson/V13PO01.png
#   inflating: wave/training/parkinson/V13PO02.png
#   inflating: wave/training/parkinson/V13PO03.png
#   inflating: wave/training/parkinson/V14PO02.png
#   inflating: wave/training/parkinson/V15PO01.png
#   inflating: wave/training/parkinson/V15PO02.png
#   inflating: wave/training/parkinson/V15PO03.png

# %%
import tensorflow_hub as hub
import tensorflow as tf
import PIL.Image as Image
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                        zoom_range=0.2,
                                        horizontal_flip=True,
                                        width_shift_range=0.3,
                                        height_shift_range=0.3)
x_train = train_datagen.flow_from_directory(
        '/content/spiral/training',
        target_size = (224,224),
        # color_mode="grayscale",
        batch_size=4,
        class_mode='binary'
        )
# Out:
# Found 77 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
x_test = test_datagen.flow_from_directory(
        '/content/spiral/testing',
        target_size=(224,224),
        batch_size=4,
        # color_mode="grayscale",
        class_mode='binary')
# Out:
# Found 30 images belonging to 2 classes.

# %%
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

pretrained_model_without_top_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224,224,3), trainable=False)

# %%
classes = 1

img_model = tf.keras.Sequential([
  pretrained_model_without_top_layer,
  tf.keras.layers.Dense(classes)
])

img_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense_2 (Dense)             (None, 1)                 1281
#
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
img_model.compile(
  optimizer="adam",
  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),  
  metrics=['acc'])

history = img_model.fit(x_train,epochs=20)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 5s 157ms/step - loss: 0.8041 - acc: 0.5325
# Epoch 2/20
# 20/20 [==============================] - 4s 194ms/step - loss: 0.7080 - acc: 0.5195
# Epoch 3/20
# 20/20 [==============================] - 4s 190ms/step - loss: 0.5634 - acc: 0.7403
# Epoch 4/20
# 20/20 [==============================] - 4s 193ms/step - loss: 0.4851 - acc: 0.7273
# Epoch 5/20
# 20/20 [==============================] - 4s 192ms/step - loss: 0.4631 - acc: 0.7403
# Epoch 6/20
# 20/20 [==============================] - 3s 169ms/step - loss: 0.5016 - acc: 0.7922
# Epoch 7/20
# 20/20 [==============================] - 3s 149ms/step - loss: 0.4325 - acc: 0.7662
# Epoch 8/20
# 20/20 [==============================] - 4s 201ms/step - loss: 0.4697 - acc: 0.8052
# Epoch 9/20
# 20/20 [==============================] - 4s 190ms/step - loss: 0.4250 - acc: 0.7532
# Epoch 10/20
# 20/20 [==============================] - 3s 151ms/step - loss: 0.4379 - acc: 0.7792
# Epoch 11/20
# 20/20 [==============================] - 3s 151ms/step - loss: 0.4014 - acc: 0.8442
# Epoch 12/20
# 20/20 [==============================] - 4s 219ms/step - loss: 0.3954 - acc: 0.7403
# Epoch 13/20
# 20/20 [==============================] - 3s 153ms/step - loss: 0.3852 - acc: 0.8182
# Epoch 14/20
# 20/20 [==============================] - 3s 148ms/step - loss: 0.4160 - acc: 0.7662
# Epoch 15/20
# 20/20 [==============================] - 3s 149ms/step - loss: 0.4114 - acc: 0.7792
# Epoch 16/20
# 20/20 [==============================] - 3s 147ms/step - loss: 0.3814 - acc: 0.8442
# Epoch 17/20
# 20/20 [==============================] - 3s 149ms/step - loss: 0.3630 - acc: 0.7922
# Epoch 18/20
# 20/20 [==============================] - 3s 150ms/step - loss: 0.3800 - acc: 0.8052
# Epoch 19/20
# 20/20 [==============================] - 3s 151ms/step - loss: 0.3602 - acc: 0.8052
# Epoch 20/20
# 20/20 [==============================] - 3s 150ms/step - loss: 0.3785 - acc: 0.8182

# %%
img_model.evaluate(x_train)
# Out:
# 20/20 [==============================] - 4s 152ms/step - loss: 0.3325 - acc: 0.8961
# [0.3325190246105194, 0.8961039185523987]

# %% [markdown]
# Tappy Keyboard Stroke dataset for Parkinson

# %%
# ! kaggle datasets download -d valkling/tappy-keystroke-data-with-parkinsons-patients
# Out:
# Downloading tappy-keystroke-data-with-parkinsons-patients.zip to /content
#  86% 82.0M/95.8M [00:01<00:00, 61.0MB/s]
# 100% 95.8M/95.8M [00:01<00:00, 79.2MB/s]

# %%
# ! unzip tappy-keystroke-data-with-parkinsons-patients.zip
# Out:
# Archive:  tappy-keystroke-data-with-parkinsons-patients.zip
#   inflating: Archived-Data/Tappy Data/0EA27ICBLF_1607.txt
#   inflating: Archived-users/Archived users/User_VZWQROMTLO.txt
#   inflating: Archived-users/Archived users/User_WBS5I7VF1G.txt
#   inflating: Archived-users/Archived users/User_WCNUFGGLYB.txt
#   inflating: Archived-users/Archived users/User_WDNE1Q9EHT.txt
#   inflating: Archived-users/Archived users/User_WXNQ0QM0XD.txt
#   inflating: Archived-users/Archived users/User_WY25WHLA9D.txt
#   inflating: Archived-users/Archived users/User_X7PEJ5EG77.txt
#   inflating: Archived-users/Archived users/User_XPHHPHIVZ4.txt
#   inflating: Archived-users/Archived users/User_XQIXWF0BXG.txt
#   inflating: Archived-users/Archived users/User_XWAX2IHF3O.txt
#   inflating: Archived-users/Archived users/User_YAJFHG6OHD.txt
#   inflating: Archived-users/Archived users/User_YFZEXV85OS.txt
#   inflating: Archived-users/Archived users/User_YI43UM1CEH.txt
#   inflating: Archived-users/Archived users/User_YIA9DW5AGQ.txt
#   inflating: Archived-users/Archived users/User_YNVRRFC8S4.txt
#   inflating: Archived-users/Archived users/User_YQSGN9BMVK.txt
#   inflating: Archived-users/Archived users/User_YWAWVFZZZE.txt
#   inflating: Archived-users/Archived users/User_YWMIQIQND3.txt
#   inflating: Archived-users/Archived users/User_YYPKGX6B24.txt
#   inflating: Archived-users/Archived users/User_Z2UPVHHGBE.txt
#   inflating: Archived-users/Archived users/User_ZCPALNB4ZM.txt
#   inflating: Archived-users/Archived users/User_ZEA4RST93H.txt
#   inflating: Archived-users/Archived users/User_ZI1KGKLCD5.txt
#   inflating: Archived-users/Archived users/User_ZIUU38ZJXA.txt
#   inflating: Archived-users/Archived users/User_ZPXSHZSGKI.txt
#   inflating: Archived-users/Archived users/User_ZQ4UHHUPNZ.txt
#   inflating: Archived-users/Archived users/User_ZT9ASWFCFS.txt
#   inflating: Archived-users/Archived users/User_ZWBPPNQCUX.txt
#   inflating: Archived-users/Archived users/User_ZWHGXDUDLG.txt
#   inflating: Archived-users/Archived users/User_ZY9CCHSPF2.txt
#   inflating: Archived-users/Archived users/User_ZYWLN4JVLA.txt

# %%
import os
import re
from functools import partial
user_root = "/content/Archived-users/Archived users/"
user_fn_list = os.listdir(user_root)

# %%
def read_one_file(fn, root):
    out = dict()
    with open(root + fn) as f:
        for line in f.readlines():
            k, v = line.split(": ")
            out[k] = v.strip()
            out['ID'] = re.findall(r'_(\w+)\.', fn)[0]
    return out

# %%
users_list = list(map(partial(read_one_file, root=user_root), user_fn_list))

# %%
users = pd.DataFrame(users_list)
users.replace('------', np.nan, inplace=True)
users.replace('', np.nan, inplace=True)
users['Levadopa'] = users['Levadopa'] == 'True'
users['MAOB'] = users['MAOB'] == 'True'
users['Parkinsons'] = users['Parkinsons'] == 'True'
users['Tremors'] = users['Tremors'] == 'True'
users['Other'] = users['Other'] == 'True'

# %%
users.head()
# Out:
#   BirthYear          ID  Gender  Parkinsons  Tremors DiagnosisYear  Sided  \
# 0      1937  BIGWMXFU3B    Male        True    False          2016  Right
# 1      1946  STW9PUPHWN    Male       False    False           NaN   None
# 2      1952  LFKWFNOFEM  Female        True     True          2017   None
# 3      1947  927ZLCPEJM    Male        True     True          2013  Right
# 4      1937  ZCPALNB4ZM  Female        True     True          2015  Right
#
#         UPDRS  Impact  Levadopa     DA   MAOB  Other
# 0  Don't know  Medium      True  False  False  False
# 1  Don't know     NaN     False  False  False  False
# 2  Don't know    Mild      True  False  False  False
# 3  Don't know  Medium     False   True   True  False
# 4  Don't know  Severe      True  False  False   True

# %%
keys_root = "/content/Archived-Data/Tappy Data/"
keys_fn_list = os.listdir(keys_root)

# %%
sample = pd.read_csv(keys_root + keys_fn_list[0], delimiter='\t', header=None, usecols=range(8))
sample.columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime']
sample.head()
# Out:
#            ID    Date            TS Hand  HoldTime Direction  LatencyTime  \
# 0  XWAX2IHF3O  160623  02:23:49.064    R      96.7        RR        293.0
# 1  XWAX2IHF3O  160623  02:23:49.353    L      13.7        RL        194.3
# 2  XWAX2IHF3O  160623  02:23:49.479    L     139.6        LL        194.3
# 3  XWAX2IHF3O  160623  02:23:49.785    L      68.4        LL        115.2
# 4  XWAX2IHF3O  160623  02:23:49.817    R     100.6        LR        115.2
#
#    FlightTime
# 0       205.1
# 1       274.4
# 2       274.4
# 3       238.3
# 4       238.3

# %%
from pandas.errors import EmptyDataError
def read_one_key_file(fn, root):
    try:
        df = pd.read_csv(root + fn, delimiter='\t', header=None, error_bad_lines=False,
                         usecols=range(8), low_memory=False,
                        dtype={0:'str', 1:'str', 2:'str', 3:'str', 4:'float', 5:'str', 6:'float', 7:'float'})
        df.columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime']
    except ValueError:
        # should try to remove the bad lines and return
#         df = pd.DataFrame(columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime'])
        try:
            df = pd.read_csv(root + fn, delimiter='\t', header=None, error_bad_lines=False,
                             usecols=range(8), low_memory=False)
            df.columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime']
            df = df[df['ID'].apply(lambda x: len(str(x)) == 10)
                   & df['Date'].apply(lambda x: len(str(x)) == 6)
                   & df['TS'].apply(lambda x: len(str(x)) == 12)
                   & np.in1d(df['Hand'], ["L", "R", "S"])
                   & df['HoldTime'].apply(lambda x: re.search(r"[^\d.]", str(x)) is None)
                   & np.in1d(df['Direction'], ['LL', 'LR', 'RL', 'RR', 'LS', 'SL', 'RS', 'SR', 'RR'])
                   & df['LatencyTime'].apply(lambda x: re.search(r"[^\d.]", str(x)) is None)
                   & df['FlightTime'].apply(lambda x: re.search(r"[^\d.]", str(x)) is None)]
            df['HoldTime'] = df['HoldTime'].astype(np.float)
            df['LatencyTime'] = df['HoldTime'].astype(np.float)
            df['FlightTime'] = df['HoldTime'].astype(np.float)
        except EmptyDataError:
            df =  pd.DataFrame(columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime'])
    except EmptyDataError:
        df =  pd.DataFrame(columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime'])
    return df

# %%
keys_list = list(map(partial(read_one_key_file, root=keys_root), keys_fn_list))
# Out:
# <ipython-input-55-ae88b3b6fa7d>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   keys_list = list(map(partial(read_one_key_file, root=keys_root), keys_fn_list))
# <ipython-input-54-4b959e84814f>:23: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['HoldTime'] = df['HoldTime'].astype(np.float)
# <ipython-input-54-4b959e84814f>:24: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['LatencyTime'] = df['HoldTime'].astype(np.float)
# <ipython-input-54-4b959e84814f>:25: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['FlightTime'] = df['HoldTime'].astype(np.float)

# %%
keys = pd.concat(keys_list, ignore_index=True, axis=0)

# %%
keys.head()
# Out:
#            ID    Date            TS Hand  HoldTime Direction  LatencyTime  \
# 0  XWAX2IHF3O  160623  02:23:49.064    R      96.7        RR        293.0
# 1  XWAX2IHF3O  160623  02:23:49.353    L      13.7        RL        194.3
# 2  XWAX2IHF3O  160623  02:23:49.479    L     139.6        LL        194.3
# 3  XWAX2IHF3O  160623  02:23:49.785    L      68.4        LL        115.2
# 4  XWAX2IHF3O  160623  02:23:49.817    R     100.6        LR        115.2
#
#    FlightTime
# 0       205.1
# 1       274.4
# 2       274.4
# 3       238.3
# 4       238.3

# %%
key_id_set = set(keys['ID'].unique())
print("total user ids in key logs: {0}".format(len(key_id_set)))
user_id_set = set(users['ID'].unique())
print("total user ids in user info: {0}".format(len(user_id_set)))
overlap_id_set = key_id_set.intersection(user_id_set)
print("overlapping ids: {0}".format(len(overlap_id_set)))
diff_id_set = key_id_set.symmetric_difference(user_id_set)
print("non-matching ids: {0}".format(len(diff_id_set)))
# Out:
# total user ids in key logs: 277
# total user ids in user info: 227
# overlapping ids: 217
# non-matching ids: 70

# %%
sufficient_keys = keys.groupby('ID').size() >= 2000
user_w_sufficient_data = set(sufficient_keys.index[sufficient_keys])
user_eligible = set(users[((users['Parkinsons']) & (users['Impact'] == 'Mild') 
                       | (~users['Parkinsons']))
                      & (~users['Levadopa'])]['ID'])
user_valid = user_w_sufficient_data.intersection(user_eligible)

# %%
valid_keys = keys[np.isin(keys['ID'], list(user_valid))]

valid_keys.shape
# Out:
# (3658979, 8)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import cross_validate, cross_val_score, train_test_split, KFold, StratifiedKFold
from scipy.stats import skew, kurtosis
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone, BaseEstimator, TransformerMixin

import os
from functools import partial
import re
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %%
hold_by_user =  valid_keys[valid_keys['Hand'] != 'S'].groupby(['ID', 'Hand'])['HoldTime'].agg([np.mean, np.std, skew, kurtosis])

# %%
hold_by_user.head(10)
# Out:
#                        mean        std      skew  kurtosis
# ID         Hand
# 48DZPAJ5NS L     125.093648  21.344768  0.433347  5.116874
#            R     125.944823  20.440962  0.122130  5.692705
# 5PQVTWULAC L     131.724002  37.064749  0.978465  7.127388
#            R     113.398834  29.041533 -0.062599  0.907739
# 5USOYSDCXB L      72.152276  26.076473  0.141122  0.888681
#            R      74.706504  23.756390 -0.265969  1.671472
# 6LB9FQABZQ L     126.497906  66.799577  0.268232  0.026491
#            R      98.527829  48.547446  0.054386  0.672722
# 81NEUZEBXI L     129.715948  38.823109  0.309899  1.394108
#            R     128.692870  41.264629  0.511903  1.878552

# %%
latency_by_user = valid_keys[np.isin(valid_keys['Direction'], ['LL', 'LR', 'RL', 'RR'])].groupby(['ID', 'Direction'])['LatencyTime'].agg([np.mean, np.std, skew, kurtosis])

# %%
latency_by_user.head(10)
# Out:
#                             mean         std      skew   kurtosis
# ID         Direction
# 48DZPAJ5NS LL         300.190663   81.809939  0.361579  -0.565283
#            LR         335.274126   81.450453  0.020670  -0.705773
#            RL         321.053098   88.512695  0.143658  -0.929929
#            RR         332.504906   90.989458 -0.052046  -1.042327
# 5PQVTWULAC LL         358.358252  121.124398  0.928077   2.024448
#            LR         478.761804  128.429826 -0.016904  -0.323100
#            RL         454.325847  135.090148  0.386154  -0.000415
#            RR         383.152730  137.104995  0.611069   0.306093
# 5USOYSDCXB LL         177.817371   85.552371  1.835981   8.081838
#            LR         139.949558   85.228366  3.126761  14.456914

# %%
hold_by_user_flat = hold_by_user.unstack()
hold_by_user_flat.columns = ['_'.join(col).strip() for col in hold_by_user_flat.columns.values]
hold_by_user_flat['mean_hold_diff'] = hold_by_user_flat['mean_L'] - hold_by_user_flat['mean_R']
hold_by_user_flat.head()
# Out:
#                 mean_L      mean_R      std_L      std_R    skew_L    skew_R  \
# ID
# 48DZPAJ5NS  125.093648  125.944823  21.344768  20.440962  0.433347  0.122130
# 5PQVTWULAC  131.724002  113.398834  37.064749  29.041533  0.978465 -0.062599
# 5USOYSDCXB   72.152276   74.706504  26.076473  23.756390  0.141122 -0.265969
# 6LB9FQABZQ  126.497906   98.527829  66.799577  48.547446  0.268232  0.054386
# 81NEUZEBXI  129.715948  128.692870  38.823109  41.264629  0.309899  0.511903
#
#             kurtosis_L  kurtosis_R  mean_hold_diff
# ID
# 48DZPAJ5NS    5.116874    5.692705       -0.851175
# 5PQVTWULAC    7.127388    0.907739       18.325168
# 5USOYSDCXB    0.888681    1.671472       -2.554228
# 6LB9FQABZQ    0.026491    0.672722       27.970077
# 81NEUZEBXI    1.394108    1.878552        1.023078

# %%
latency_by_user_flat = latency_by_user.unstack()
latency_by_user_flat.columns = ['_'.join(col).strip() for col in latency_by_user_flat.columns.values]
latency_by_user_flat['mean_LR_RL_diff'] = latency_by_user_flat['mean_LR'] - latency_by_user_flat['mean_RL']
latency_by_user_flat['mean_LL_RR_diff'] = latency_by_user_flat['mean_LL'] - latency_by_user_flat['mean_RR']
latency_by_user_flat.head()
# Out:
#                mean_LL     mean_LR     mean_RL     mean_RR      std_LL  \
# ID
# 48DZPAJ5NS  300.190663  335.274126  321.053098  332.504906   81.809939
# 5PQVTWULAC  358.358252  478.761804  454.325847  383.152730  121.124398
# 5USOYSDCXB  177.817371  139.949558  145.719255  176.761511   85.552371
# 6LB9FQABZQ  164.435681  147.560261  140.279823  153.614464  115.526340
# 81NEUZEBXI  290.175870  283.684444  250.171244  298.446718  104.348556
#
#                 std_LR      std_RL      std_RR   skew_LL   skew_LR   skew_RL  \
# ID
# 48DZPAJ5NS   81.450453   88.512695   90.989458  0.361579  0.020670  0.143658
# 5PQVTWULAC  128.429826  135.090148  137.104995  0.928077 -0.016904  0.386154
# 5USOYSDCXB   85.228366   93.083272   83.494383  1.835981  3.126761  2.885283
# 6LB9FQABZQ  124.538329   96.912507  108.109519  2.213465  2.475045  2.705128
# 81NEUZEBXI  115.299929  121.395210  110.748243 -0.004796 -0.044029  0.535980
#
#              skew_RR  kurtosis_LL  kurtosis_LR  kurtosis_RL  kurtosis_RR  \
# ID
# 48DZPAJ5NS -0.052046    -0.565283    -0.705773    -0.929929    -1.042327
# 5PQVTWULAC  0.611069     2.024448    -0.323100    -0.000415     0.306093
# 5USOYSDCXB  1.269504     8.081838    14.456914    11.615300     6.435207
# 6LB9FQABZQ  2.303681     6.808226     7.120620    11.073373     7.515809
# 81NEUZEBXI -0.172322    -0.741370    -1.120918    -1.034998    -0.787168
#
#             mean_LR_RL_diff  mean_LL_RR_diff
# ID
# 48DZPAJ5NS        14.221029       -32.314242
# 5PQVTWULAC        24.435956       -24.794478
# 5USOYSDCXB        -5.769697         1.055860
# 6LB9FQABZQ         7.280438        10.821217
# 81NEUZEBXI        33.513200        -8.270847

# %%
combined = pd.concat([hold_by_user_flat, latency_by_user_flat], axis=1)

# %%
combined.head()
# Out:
#                 mean_L      mean_R      std_L      std_R    skew_L    skew_R  \
# ID
# 48DZPAJ5NS  125.093648  125.944823  21.344768  20.440962  0.433347  0.122130
# 5PQVTWULAC  131.724002  113.398834  37.064749  29.041533  0.978465 -0.062599
# 5USOYSDCXB   72.152276   74.706504  26.076473  23.756390  0.141122 -0.265969
# 6LB9FQABZQ  126.497906   98.527829  66.799577  48.547446  0.268232  0.054386
# 81NEUZEBXI  129.715948  128.692870  38.823109  41.264629  0.309899  0.511903
#
#             kurtosis_L  kurtosis_R  mean_hold_diff     mean_LL  ...   skew_LL  \
# ID                                                              ...
# 48DZPAJ5NS    5.116874    5.692705       -0.851175  300.190663  ...  0.361579
# 5PQVTWULAC    7.127388    0.907739       18.325168  358.358252  ...  0.928077
# 5USOYSDCXB    0.888681    1.671472       -2.554228  177.817371  ...  1.835981
# 6LB9FQABZQ    0.026491    0.672722       27.970077  164.435681  ...  2.213465
# 81NEUZEBXI    1.394108    1.878552        1.023078  290.175870  ... -0.004796
#
#              skew_LR   skew_RL   skew_RR  kurtosis_LL  kurtosis_LR  \
# ID
# 48DZPAJ5NS  0.020670  0.143658 -0.052046    -0.565283    -0.705773
# 5PQVTWULAC -0.016904  0.386154  0.611069     2.024448    -0.323100
# 5USOYSDCXB  3.126761  2.885283  1.269504     8.081838    14.456914
# 6LB9FQABZQ  2.475045  2.705128  2.303681     6.808226     7.120620
# 81NEUZEBXI -0.044029  0.535980 -0.172322    -0.741370    -1.120918
#
#             kurtosis_RL  kurtosis_RR  mean_LR_RL_diff  mean_LL_RR_diff
# ID
# 48DZPAJ5NS    -0.929929    -1.042327        14.221029       -32.314242
# 5PQVTWULAC    -0.000415     0.306093        24.435956       -24.794478
# 5USOYSDCXB    11.615300     6.435207        -5.769697         1.055860
# 6LB9FQABZQ    11.073373     7.515809         7.280438        10.821217
# 81NEUZEBXI    -1.034998    -0.787168        33.513200        -8.270847
#
# [5 rows x 27 columns]

# %%
full_set = pd.merge(combined.reset_index(), users[['ID', 'Parkinsons']], on='ID')
full_set.set_index('ID', inplace=True)
# full_set.dropna(inplace=True)  # should investigate why there are NAs despite choosing sequence length >= 2000
full_set.shape
# Out:
# (52, 28)

# %%
full_set.head()
# Out:
#                 mean_L      mean_R      std_L      std_R    skew_L    skew_R  \
# ID
# 48DZPAJ5NS  125.093648  125.944823  21.344768  20.440962  0.433347  0.122130
# 5PQVTWULAC  131.724002  113.398834  37.064749  29.041533  0.978465 -0.062599
# 5USOYSDCXB   72.152276   74.706504  26.076473  23.756390  0.141122 -0.265969
# 6LB9FQABZQ  126.497906   98.527829  66.799577  48.547446  0.268232  0.054386
# 81NEUZEBXI  129.715948  128.692870  38.823109  41.264629  0.309899  0.511903
#
#             kurtosis_L  kurtosis_R  mean_hold_diff     mean_LL  ...   skew_LR  \
# ID                                                              ...
# 48DZPAJ5NS    5.116874    5.692705       -0.851175  300.190663  ...  0.020670
# 5PQVTWULAC    7.127388    0.907739       18.325168  358.358252  ... -0.016904
# 5USOYSDCXB    0.888681    1.671472       -2.554228  177.817371  ...  3.126761
# 6LB9FQABZQ    0.026491    0.672722       27.970077  164.435681  ...  2.475045
# 81NEUZEBXI    1.394108    1.878552        1.023078  290.175870  ... -0.044029
#
#              skew_RL   skew_RR  kurtosis_LL  kurtosis_LR  kurtosis_RL  \
# ID
# 48DZPAJ5NS  0.143658 -0.052046    -0.565283    -0.705773    -0.929929
# 5PQVTWULAC  0.386154  0.611069     2.024448    -0.323100    -0.000415
# 5USOYSDCXB  2.885283  1.269504     8.081838    14.456914    11.615300
# 6LB9FQABZQ  2.705128  2.303681     6.808226     7.120620    11.073373
# 81NEUZEBXI  0.535980 -0.172322    -0.741370    -1.120918    -1.034998
#
#             kurtosis_RR  mean_LR_RL_diff  mean_LL_RR_diff  Parkinsons
# ID
# 48DZPAJ5NS    -1.042327        14.221029       -32.314242        True
# 5PQVTWULAC     0.306093        24.435956       -24.794478        True
# 5USOYSDCXB     6.435207        -5.769697         1.055860        True
# 6LB9FQABZQ     7.515809         7.280438        10.821217       False
# 81NEUZEBXI    -0.787168        33.513200        -8.270847       False
#
# [5 rows x 28 columns]

# %%
! pip install umap-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.8/dist-packages (0.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.7.3)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (0.5.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (6.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn) (3.12.0)

# %%
import umap.umap_ as umap
umapModel = umap.UMAP()
embed = umapModel.fit_transform(full_set.iloc[:, :-1], full_set.iloc[:, -1])

# %%
from sklearn.svm import LinearSVC
keystroke_model = LinearSVC()
rs = 42

train_X = np.concatenate([full_set.iloc[:, :-1], pd.DataFrame(embed)], axis=1)
train_y = full_set.iloc[:, -1]

scoring = ['accuracy', 'f1', 'roc_auc']
scores= cross_validate(
    keystroke_model,
    train_X,
    train_y,
    cv=StratifiedKFold(n_splits=5, random_state=rs,shuffle=True),
    scoring=scoring,
    return_train_score=True
)

# %%
result = pd.DataFrame(scores)
result.index.name = "fold"
result
# Out:
#       fit_time  score_time  test_accuracy  train_accuracy   test_f1  train_f1  \
# fold
# 0     0.006816    0.004578       1.000000        0.951220  1.000000  0.937500
# 1     0.006793    0.004899       0.909091        0.975610  0.857143  0.967742
# 2     0.006493    0.004185       1.000000        0.928571  1.000000  0.903226
# 3     0.013930    0.021113       0.900000        0.976190  0.888889  0.967742
# 4     0.006776    0.003608       1.000000        0.976190  1.000000  0.967742
#
#       test_roc_auc  train_roc_auc
# fold
# 0         1.000000       0.923077
# 1         0.750000       0.961538
# 2         1.000000       0.871605
# 3         0.833333       0.962963
# 4         1.000000       0.937500

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('stsb-distilbert-base')
model.max_seq_length = 128
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-be5489f7506e> in <module>
# ----> 1 from sentence_transformers import SentenceTransformer, util
#       2 model = SentenceTransformer('stsb-distilbert-base')
#       3 model.max_seq_length = 128
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
IMG_SIZE = 224
size = (IMG_SIZE,IMG_SIZE)
img_model = tf.keras.applications.MobileNet(input_shape = (IMG_SIZE, IMG_SIZE, 3), include_top = False, weights = 'imagenet' )

# %%
def get_textEmbeddings(model,text):
    text_embedding = model.encode(text, convert_to_tensor=True)
    return text_embedding

# %%
def get_imageEmbeddings(model,imagePath):
    image = tf.keras.preprocessing.image.load_img(imagePath,target_size= size)
    input_arr = tf.keras.preprocessing.image.img_to_array(image)
    input_arr = np.array([input_arr])
    img_embeddings = model(input_arr)
    meanImgEmb1 = np.mean(img_embeddings,axis =0)
    meanImgEmb2 = np.mean(meanImgEmb1,axis=0)
    meanImgEmb = np.mean(meanImgEmb2,axis=0)
    return meanImgEmb

# %%
import pickle
with open('./textEmb','wb') as handle:
    pickle.dump(text_embeddings,handle)
with open('./imgEmb','wb') as handle:
    pickle.dump(image_embeddings,handle)

# %%
keyList=[]
cembList=[]
imageList=[]
titleList=[]
for index, row in X_train.iterrows():
    #start_time=time.time()
    txt_emb = text_embeddings[row[0]]
    img_emb = image_embeddings[row[0]] 
    cmb_emb = np.concatenate((txt_emb,img_emb),axis=0)
    norm = np.linalg.norm(cmb_emb)
    cmb_emb_normal = cmb_emb/norm
    keyList.append(row[0])
    cembList.append(cmb_emb_normal)
    imageList.append(row[1])
    titleList.append(row[3])
